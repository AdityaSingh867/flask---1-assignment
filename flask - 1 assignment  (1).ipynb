# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Flask is a micro web framework written in Python.
#
# ADVANTAGES - In flask we connect different code language with each other like python to html , python to c++ , python to JAVA , python to C# , etc

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# from flask import Flask
#
# apple = Flask(__name__)
#
# @apple.route('/file_')
#
# def file_():
#
#     return'<h1>Hello World!!</h1>'
#
# if __name__=="__main__":
#
#     apple.run(host="0.0.0.0")

# %%
from IPython import display

# %%
display.Image("./Screenshot (20).png")

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# from flask import Flask
#
# apple = Flask(__name__)
#
# @apple.route('/welcome')
#
# def test():
#
#     return '<h1>Welcome to ABC Corporation</h1>  Company Name: ABC Corporation , Location: India , Contact Detail: 999-999-9999'
#
# if __name__=="__main__":
#
#     apple.run(host="0.0.0.0")

# %%
display.Image('./Screenshot (21).png')

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# The url_for() function is very useful for dynamically building a URL for a specific function.

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing is the technique used to map the specific URL with the associated function intended to perform some task . app routing is connect the code text which we want to give client to url.
